# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectFromModel
from sklearn.inspection import permutation_importance
from sklearn.metrics import roc_auc_score,accuracy_score
import random

# %%
df = pd.read_csv('final_data_1.csv')

# %%
df.sample(10)
# Out:
#       Unnamed: 0     ID        time  mood  circumplex.arousal  \
# 296          296  14.08  2014-03-20  6.40           -0.145140
# 957          957  14.26  2014-05-12  6.40            0.156768
# 643          643  14.17  2014-03-12  6.40            0.458676
# 917          917  14.26  2014-04-01  6.60            0.760584
# 412          412  14.12  2014-04-18  6.60           -0.748957
# 403          403  14.12  2014-04-09  5.25            0.156768
# 1243        1243  14.33  2014-05-07  5.00           -0.220617
# 76            76  14.02  2014-04-14  8.00            1.288923
# 834          834  14.24  2014-04-25  6.20            0.458676
# 378          378  14.09  2014-04-25  7.25            0.534153
#
#       circumplex.valence  activity    screen      call       sms  ...  \
# 296             0.260788 -0.620342 -1.034151 -0.712555  0.028282  ...
# 957            -0.660346 -1.069619  0.535330 -0.712555 -0.511811  ...
# 643            -1.120914 -0.616354 -0.145395 -0.712555 -0.511811  ...
# 917            -2.042048 -0.341735 -0.434972  0.484239  0.568376  ...
# 412             0.260788 -0.381106  0.006439 -0.712555 -0.511811  ...
# 403            -2.732899  0.530204  1.119056 -0.712555 -0.511811  ...
# 1243           -2.732899 -1.214449 -0.585645 -0.413356  0.028282  ...
# 76              0.721356  0.759873 -0.671304  1.681032  3.268841  ...
# 834            -1.005772 -0.525171 -0.726439  1.980231  0.028282  ...
# 378             0.721356  0.000680 -0.997962 -0.592875 -0.187755  ...
#
#       appCat.finance  appCat.game  appCat.office  appCat.other  appCat.social  \
# 296        -0.445458    -0.213581      -0.165525     -0.304610      -0.271979
# 957         0.144438     0.411853      -0.121498     -0.348445       0.932420
# 643        -0.184629    -0.404390      -0.157068     -0.368729       0.133170
# 917        -0.096461    -0.011016      -0.155382     -0.124541      -0.067207
# 412        -0.468280    -0.437693      -0.165525     -0.287877       1.085978
# 403        -0.106702    -0.084567       0.002672     -0.323237       1.535712
# 1243       -0.376643    -0.299697      -0.039739     -0.321952       0.601739
# 76          0.182067    -0.385205      -0.125663     -0.375999      -0.607355
# 834        -0.092925    -0.133808      -0.131767     -0.262217      -0.576894
# 378         0.015742    -0.279551      -0.160791     -0.364474      -0.638464
#
#       appCat.travel  appCat.unknown  appCat.utilities  appCat.weather  \
# 296       -0.274211       -0.392016         -0.317412       -0.122303
# 957       -0.274211        0.380985         -0.157793       -0.628896
# 643       -0.174840       -0.237416         -0.237434       -0.628896
# 917       -0.187374       -0.179148          0.049003       -0.271551
# 412        0.776619       -0.365453         -0.290737       -0.221869
# 403       -0.128845        0.706585         -0.202152        0.269924
# 1243      -0.269437       -0.392016         -0.296296        0.215750
# 76        -0.188195       -0.392016          0.242378       -0.522981
# 834       -0.145602       -0.392016          0.215683       -0.522981
# 378        0.117039        0.056785         -0.227921       -0.060747
#
#       mood_class
# 296            1
# 957            1
# 643            1
# 917            1
# 412            1
# 403            1
# 1243           1
# 76             2
# 834            1
# 378            2
#
# [10 rows x 23 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0     ID        time      mood  circumplex.arousal  \
# 0              0  14.01  2014-02-26  6.250000           -0.220617
# 1              1  14.01  2014-02-27  6.333333            0.156768
# 2              2  14.01  2014-03-21  6.200000            0.458676
# 3              3  14.01  2014-03-22  6.400000            1.062492
# 4              4  14.01  2014-03-23  6.800000            0.458676
# ...          ...    ...         ...       ...                 ...
# 1263        1263  14.33  2014-05-27  6.200000           -0.748957
# 1264        1264  14.33  2014-05-28  8.200000            0.156768
# 1265        1265  14.33  2014-05-29  7.000000           -1.855953
# 1266        1266  14.33  2014-05-30  6.800000           -1.050865
# 1267        1267  14.33  2014-05-31  7.000000           -2.862313
#
#       circumplex.valence  activity    screen      call       sms  ...  \
# 0               0.145647 -0.650267 -0.652424 -0.413356  0.568376  ...
# 1              -0.813869 -0.838609 -0.715377 -0.712555 -0.511811  ...
# 2              -1.120914  0.194961  2.619738  1.082636 -0.511811  ...
# 3              -0.430063  1.290503  0.057883  0.185040  0.028282  ...
# 4               0.260788  0.287554  0.194597 -0.712555 -0.511811  ...
# ...                  ...       ...       ...       ...       ...  ...
# 1263           -0.660346 -1.097846 -0.386298 -0.413356  0.568376  ...
# 1264            1.181923 -0.132635  1.828020  2.279429  0.028282  ...
# 1265            0.721356  0.571090 -0.498959  0.783437  0.028282  ...
# 1266           -2.502616  0.821955  0.784119  0.484239  0.244320  ...
# 1267            0.721356  0.080015  0.011292 -0.533036 -0.187755  ...
#
#       appCat.finance  appCat.game  appCat.office  appCat.other  appCat.social  \
# 0          -0.294904     0.140028      -0.102501     -0.297732      -0.050960
# 1          -0.584370    -0.345920      -0.165525     -0.371956       0.151018
# 2           0.036481    -0.110838      -0.004564      0.205614       1.830138
# 3          -0.320260    -0.060984      -0.165525     -0.171206      -0.397747
# 4          -0.040474    -0.193701      -0.165525     -0.238582      -0.145215
# ...              ...          ...            ...           ...            ...
# 1263        0.617367    -0.196147      -0.165525     -0.052676       0.462299
# 1264        1.118381     0.190786       0.169013      0.977825       2.297035
# 1265       -0.523613    -0.144859       0.033511     -0.354658       0.341597
# 1266        0.717153     0.074937       0.024839     -0.292369       1.095284
# 1267       -0.209877     0.442566      -0.153313      0.074035      -0.293953
#
#       appCat.travel  appCat.unknown  appCat.utilities  appCat.weather  \
# 0         -0.260896        0.106613         -0.024226       -0.563736
# 1         -0.205902       -0.162799         -0.269501       -0.628896
# 2          1.746079       -0.392016          3.649738       -0.457982
# 3         -0.191882       -0.392016          0.461906        0.604859
# 4         -0.274211       -0.392016         -0.118072        0.598445
# ...             ...             ...               ...             ...
# 1263      -0.274211       -0.392016          0.054772       -0.260677
# 1264      -0.274211       -0.392016         -0.114229        1.452874
# 1265      -0.272138       -0.392016         -0.296217        0.215750
# 1266       2.048871       -0.341178          1.225211        0.784715
# 1267      -0.240845       -0.183946         -0.131782       -0.628896
#
#       mood_class
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
# ...          ...
# 1263           1
# 1264           2
# 1265           1
# 1266           1
# 1267           1
#
# [1268 rows x 23 columns]>

# %%
df.describe(include = 'all').transpose()
# Out:
#                        count unique         top freq       mean        std  \
# Unnamed: 0            1268.0    NaN         NaN  NaN      633.5  366.18438
# ID                    1268.0    NaN         NaN  NaN  14.171798   0.097925
# time                    1268     98  2014-04-16   27        NaN        NaN
# mood                  1268.0    NaN         NaN  NaN   6.990063   0.736465
# circumplex.arousal    1268.0    NaN         NaN  NaN       -0.0   1.000395
# circumplex.valence    1268.0    NaN         NaN  NaN       -0.0   1.000395
# activity              1268.0    NaN         NaN  NaN        0.0   1.000395
# screen                1268.0    NaN         NaN  NaN        0.0   1.000395
# call                  1268.0    NaN         NaN  NaN       -0.0   1.000395
# sms                   1268.0    NaN         NaN  NaN        0.0   1.000395
# appCat.builtin        1268.0    NaN         NaN  NaN        0.0   1.000395
# appCat.communication  1268.0    NaN         NaN  NaN        0.0   1.000395
# appCat.entertainment  1268.0    NaN         NaN  NaN        0.0   1.000395
# appCat.finance        1268.0    NaN         NaN  NaN       -0.0   1.000395
# appCat.game           1268.0    NaN         NaN  NaN        0.0   1.000395
# appCat.office         1268.0    NaN         NaN  NaN       -0.0   1.000395
# appCat.other          1268.0    NaN         NaN  NaN       -0.0   1.000395
# appCat.social         1268.0    NaN         NaN  NaN        0.0   1.000395
# appCat.travel         1268.0    NaN         NaN  NaN       -0.0   1.000395
# appCat.unknown        1268.0    NaN         NaN  NaN        0.0   1.000395
# appCat.utilities      1268.0    NaN         NaN  NaN       -0.0   1.000395
# appCat.weather        1268.0    NaN         NaN  NaN       -0.0   1.000395
# mood_class            1268.0    NaN         NaN  NaN   1.431388   0.506494
#
#                            min       25%       50%       75%        max
# Unnamed: 0                 0.0    316.75     633.5    950.25     1267.0
# ID                       14.01     14.08     14.16     14.26      14.33
# time                       NaN       NaN       NaN       NaN        NaN
# mood                       3.0       6.6       7.0       7.5   9.333333
# circumplex.arousal   -2.862313 -0.748957  0.156768  0.760584   3.175848
# circumplex.valence   -4.460027 -0.660346  0.260788  0.721356   3.024192
# activity             -1.233196 -0.655133 -0.231947  0.289247   4.620377
# screen                -1.27148 -0.751709 -0.197766  0.506542   6.564261
# call                 -0.712555 -0.712555 -0.413356   0.18504   8.562594
# sms                  -0.511811 -0.511811 -0.511811  0.028282   8.669773
# appCat.builtin       -0.492048 -0.404773 -0.233197  0.034238  13.200333
# appCat.communication -1.070645 -0.746681 -0.248573  0.437769   7.482199
# appCat.entertainment -0.521052 -0.513174  -0.31353  0.129244  21.086537
# appCat.finance        -0.58437 -0.528981 -0.256878  0.181392  15.970778
# appCat.game          -0.437693  -0.34466  -0.20399 -0.011016  25.085502
# appCat.office        -0.165525 -0.165525 -0.155844 -0.091866  30.944228
# appCat.other         -0.432365 -0.324255 -0.268388 -0.090515  11.103916
# appCat.social        -0.638464 -0.593385 -0.337345  0.242715  15.828061
# appCat.travel        -0.274211 -0.274211  -0.26556  -0.03901  23.004355
# appCat.unknown       -0.392016 -0.392016 -0.329299  0.024606  17.378293
# appCat.utilities     -0.317412 -0.317412 -0.292052 -0.128225  14.640886
# appCat.weather       -0.628896 -0.628896 -0.349737    0.2295  14.192297
# mood_class                 0.0       1.0       1.0       2.0        2.0

# %%
missing_data_sum = df.isnull().sum()
missing_data = pd.DataFrame({'total_missing_values': missing_data_sum,'percentage_of_missing_values': (missing_data_sum/df.shape[0])*100})
missing_data[1:]
# Out:
#                       total_missing_values  percentage_of_missing_values
# ID                                       0                           0.0
# time                                     0                           0.0
# mood                                     0                           0.0
# circumplex.arousal                       0                           0.0
# circumplex.valence                       0                           0.0
# activity                                 0                           0.0
# screen                                   0                           0.0
# call                                     0                           0.0
# sms                                      0                           0.0
# appCat.builtin                           0                           0.0
# appCat.communication                     0                           0.0
# appCat.entertainment                     0                           0.0
# appCat.finance                           0                           0.0
# appCat.game                              0                           0.0
# appCat.office                            0                           0.0
# appCat.other                             0                           0.0
# appCat.social                            0                           0.0
# appCat.travel                            0                           0.0
# appCat.unknown                           0                           0.0
# appCat.utilities                         0                           0.0
# appCat.weather                           0                           0.0
# mood_class                               0                           0.0

# %%
def is_weekend(date):
    return int(date.weekday() >= 5)

# %%
data=df

# %%
data['time'] = pd.to_datetime(data['time'])
data['weekend'] = data['time'].apply(is_weekend)

# %%
random.seed(42)
np.random.seed(42)
feature = data.drop(columns=['mood','time'])  # feature of dataset
label = data['mood']  # label
X_train, X_test, y_train, y_test = train_test_split(feature, label, test_size=0.2)

model = LinearRegression()
model.fit(X_train, y_train)
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.15710208027360262

# %%
label.info
# Out:
# <bound method Series.info of 0       6.250000
# 1       6.333333
# 2       6.200000
# 3       6.400000
# 4       6.800000
#           ...
# 1263    6.200000
# 1264    8.200000
# 1265    7.000000
# 1266    6.800000
# 1267    7.000000
# Name: mood, Length: 1268, dtype: float64>

# %% [markdown]
# ### Regression

# %%
random.seed(42)
np.random.seed(42)
# 初始化并训练随机森林回归模型
model = RandomForestRegressor()

# 定义参数空间
param_grid = {
    'bootstrap': [True],
    'n_estimators': range(1,101,10),
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['log2', 'sqrt']
}

# 初始化 GridSearchCV
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5,)

grid_search.fit(X_train, y_train.values.ravel())
t_pred = grid_search.best_estimator_.predict(X_test)

# 计算预测结果与真实标签之间的均方误差
MSE = mean_squared_error(y_test, t_pred)

print("Mean Squared Error:", MSE)

MSE = mean_absolute_error(y_test, t_pred)

print("Mean absolute Error:", MSE)
# Out:
# Mean Squared Error: 0.14162930368065788
# Mean Squared Error: 0.2674728158980127

# %%
random.seed(42)
np.random.seed(42)
# 初始化并训练随机森林回归模型
model = RandomForestRegressor()
model.fit(X_train, y_train)

# Feature selection based on feature importances
sfm = SelectFromModel(model, threshold='median')  # Select features with importance above median
sfm.fit(X_train, y_train)
X_train_selected = sfm.transform(X_train)
X_test_selected = sfm.transform(X_test)
# 定义参数空间
param_grid = {
    'bootstrap': [True],
    'n_estimators': range(1,101,10),
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['log2', 'sqrt']
}

# 初始化 GridSearchCV
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5,)

grid_search.fit(X_train, y_train.values.ravel())
t_pred = grid_search.best_estimator_.predict(X_test)

# 计算预测结果与真实标签之间的均方误差
MSE = mean_squared_error(y_test, t_pred)

print("Mean Squared Error:", MSE)
# Out:
# Mean Squared Error: 0.1429855232925298

# %%
random.seed(42)
np.random.seed(42)
# Compute permutation importance
perm_importance = permutation_importance(model, X_test, y_test, n_repeats=10, random_state=42)

# Get feature importance scores
feature_importance = perm_importance.importances_mean

# Sort feature importance scores and select features above a certain threshold
threshold = 0.0  # You can adjust the threshold based on your preference
selected_features = X_train.columns[feature_importance > threshold]

# Subset the training and testing sets with selected features
X_train_selected = X_train[selected_features]
X_test_selected = X_test[selected_features]
param_grid = {
    'bootstrap': [True],
    'n_estimators': range(1,101,10),
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['log2', 'sqrt']
}

# Initialize GridSearchCV with RandomForestRegressor
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=5,)

# Fit GridSearchCV using selected features
grid_search.fit(X_train_selected, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)

# Make predictions on test set
t_pred = grid_search.best_estimator_.predict(X_test_selected)

# Calculate mean squared error
MSE = mean_squared_error(y_test, t_pred)

print("Mean Squared Error:", MSE)

MAE = mean_absolute_error(y_test, t_pred)

print("Mean Absolute Error:", MAE)
# Out:
# Best Parameters: {'bootstrap': True, 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 91}
# Mean Squared Error: 0.1294978201956574
# Mean Absolute Error: 0.2569637386975362

# %%
random.seed(42)
np.random.seed(42)
# Combine training and testing features
X_adv = np.vstack((X_train, X_test))

# Create labels: 0 for training set, 1 for testing set
y_adv = np.hstack((np.zeros(len(X_train)), np.ones(len(X_test))))

# Initialize and train a classifier
adv_model = RandomForestClassifier()
adv_model.fit(X_adv, y_adv)

# Predict probabilities for belonging to the testing set
adv_probs = adv_model.predict_proba(X_adv)[:, 1]

# Calculate AUC score to assess similarity between sets
adv_auc = roc_auc_score(y_adv, adv_probs)
print("Adversarial AUC Score:", adv_auc)
# Out:
# Adversarial AUC Score: 1.0

# %%
correlation_matrix = data.corr()

# Extract correlations between features and target variable
correlations_with_target = correlation_matrix['mood'].drop('mood')  #'mood' is the target variable

# Print correlation coefficients
print("Correlation with target variable:")
print(correlations_with_target)
# Out:
# Correlation with target variable:
# Unnamed: 0              0.170609
# ID                      0.169282
# circumplex.arousal      0.152953
# circumplex.valence      0.684364
# activity                0.172094
# screen                  0.044452
# call                    0.031858
# sms                    -0.017278
# appCat.builtin         -0.047249
# appCat.communication    0.053590
# appCat.entertainment    0.106937
# appCat.finance         -0.015219
# appCat.game             0.063959
# appCat.office           0.030176
# appCat.other            0.083313
# appCat.social          -0.045887
# appCat.travel           0.031240
# appCat.unknown          0.037272
# appCat.utilities        0.033582
# appCat.weather         -0.024276
# mood_class              0.739938
# weekend                 0.107089
# Name: mood, dtype: float64

# %%
random.seed(42)
np.random.seed(42)
data['mood_class'] = data['mood'].apply(lambda x: 0 if x <= 4 else (1 if 5 <= x <= 7 else 2))
feature = data.drop(['mood', 'time', 'mood_class'], axis=1)
label = data['mood_class']


# feature 
X_train, X_test, y_train, y_test = train_test_split(feature, label, test_size=0.2)

model = RandomForestClassifier()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7598425196850394

# %%
random.seed(42)
np.random.seed(42)
data['mood_class'] = data['mood'].apply(lambda x: 0 if x <= 4 else (1 if 5 <= x <= 7 else 2))
feature = data.drop(['mood', 'time', 'mood_class'], axis=1)
data['mood'] = data['mood'].round()
label = data['mood']


# feature 
X_train, X_test, y_train, y_test = train_test_split(feature, label, test_size=0.2)

model = RandomForestClassifier()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6496062992125984

# %%
from sklearn.metrics import accuracy_score
from sklearn.inspection import permutation_importance

# Train your classification model (Random Forest in this case)
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Calculate permutation importance using the original test set
perm_importance = permutation_importance(model, X_test, y_test, n_repeats=10, random_state=42)

# Get feature importance scores
feature_importance = perm_importance.importances_mean

# Print feature importance scores
for i, (feat, importance) in enumerate(zip(X_test.columns, feature_importance)):
    print(f"Feature {i+1}: {feat}, Importance: {importance}")

# Sort feature importance scores and select features above a certain threshold
threshold = 0.0  # You can adjust the threshold based on your preference
selected_features = X_train.columns[feature_importance > threshold]

# Subset the training and testing sets with selected features
X_train_selected = X_train[selected_features]
X_test_selected = X_test[selected_features]

# Train the model using selected features
model.fit(X_train_selected, y_train)

# Predict on the test set using selected features
y_pred = model.predict(X_test_selected)

# Calculate accuracy using the test set with selected features
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy with selected features:", accuracy)
# Out:
# Feature 1: Unnamed: 0, Importance: 0.026771653543307038
# Feature 2: ID, Importance: 0.022834645669291297
# Feature 3: circumplex.arousal, Importance: -0.0019685039370079148
# Feature 4: circumplex.valence, Importance: 0.15748031496062986
# Feature 5: activity, Importance: 0.004724409448818889
# Feature 6: screen, Importance: 0.006692913385826759
# Feature 7: call, Importance: -0.0035433070866142113
# Feature 8: sms, Importance: -0.008267716535433133
# Feature 9: appCat.builtin, Importance: -0.006299212598425241
# Feature 10: appCat.communication, Importance: 0.0059055118110236116
# Feature 11: appCat.entertainment, Importance: -3.3306690738754695e-17
# Feature 12: appCat.finance, Importance: -0.012204724409448897
# Feature 13: appCat.game, Importance: -0.0035433070866142
# Feature 14: appCat.office, Importance: 0.0003937007874015408
# Feature 15: appCat.other, Importance: -0.0015748031496063298
# Feature 16: appCat.social, Importance: 0.012598425196850371
# Feature 17: appCat.travel, Importance: 0.003937007874015741
# Feature 18: appCat.unknown, Importance: -0.0007874015748031704
# Feature 19: appCat.utilities, Importance: 0.007480314960629908
# Feature 20: appCat.weather, Importance: 0.0027559055118109967
# Feature 21: weekend, Importance: 0.010236220472440927
# Accuracy with selected features: 0.8031496062992126

# %%
from sklearn.metrics import accuracy_score
from sklearn.inspection import permutation_importance

# Train your classification model (Random Forest in this case)
model = RandomForestClassifier()
model.fit(X_train, y_train)

# Calculate permutation importance using the original test set
perm_importance = permutation_importance(model, X_test, y_test, n_repeats=10, random_state=42)

# Get feature importance scores
feature_importance = perm_importance.importances_mean

# Print feature importance scores
for i, (feat, importance) in enumerate(zip(X_test.columns, feature_importance)):
    print(f"Feature {i+1}: {feat}, Importance: {importance}")

# Sort feature importance scores and select features above a certain threshold
threshold = 0.0  # You can adjust the threshold based on your preference
selected_features = X_train.columns[feature_importance > threshold]

# Subset the training and testing sets with selected features
X_train_selected = X_train[selected_features]
X_test_selected = X_test[selected_features]

# Train the model using selected features
param_grid = {
    'bootstrap': [True],
    'n_estimators': range(50,201,10),
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['log2', 'sqrt']
}

grid_search = GridSearchCV(estimator=RandomForestClassifier(), param_grid=param_grid, cv=5, n_jobs=-1)

# Perform grid search
grid_search.fit(X_train_selected, y_train)

# Get the best parameters
best_params = grid_search.best_params_
print("Best Parameters:", best_params)

# Predict on the test set using selected features
y_pred = grid_search.predict(X_test_selected)

# Calculate accuracy using the test set with selected features
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy with selected features:", accuracy)
# Out:
# Feature 1: Unnamed: 0, Importance: 0.03425196850393698
# Feature 2: ID, Importance: 0.016535433070866114
# Feature 3: circumplex.arousal, Importance: -0.0062992125984251855
# Feature 4: circumplex.valence, Importance: 0.1417322834645669
# Feature 5: activity, Importance: 0.018503937007873984
# Feature 6: screen, Importance: -0.002755905511811019
# Feature 7: call, Importance: -0.006692913385826759
# Feature 8: sms, Importance: -0.0059055118110236116
# Feature 9: appCat.builtin, Importance: -0.011023622047244075
# Feature 10: appCat.communication, Importance: 0.0003937007874015741
# Feature 11: appCat.entertainment, Importance: -0.0011811023622047222
# Feature 12: appCat.finance, Importance: -0.003543307086614167
# Feature 13: appCat.game, Importance: -0.0011811023622047222
# Feature 14: appCat.office, Importance: -0.0062992125984251855
# Feature 15: appCat.other, Importance: 0.0015748031496062964
# Feature 16: appCat.social, Importance: 0.004330708661417315
# Feature 17: appCat.travel, Importance: -0.0015748031496062964
# Feature 18: appCat.unknown, Importance: -0.003937007874015741
# Feature 19: appCat.utilities, Importance: 0.009055118110236205
# Feature 20: appCat.weather, Importance: -0.0015748031496062964
# Feature 21: weekend, Importance: -0.0031496062992125927
# Best Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 160}
# Accuracy with selected features: 0.8188976377952756

# %%
activity=df[df['variable']=='activity']
activity.describe(include = 'all').transpose()

# %%
circumplex_arousal=df[df['variable']=='circumplex.arousal']
activity.describe(include = 'all').transpose()

# %%
mood=df[df['variable']=='mood']
activity.describe(include = 'all').transpose()

# %%
circumplex_valence=df[df['variable']=='circumplex.valence']
activity.describe(include = 'all').transpose()

# %%
screen=df[df['variable']=='screen']
plt.figure(figsize=(6, 4))
sns.boxplot(x='value', data=df[df['variable'] == 'screen'])
plt.title('Boxplot of Data')
plt.xlabel('screen')
plt.show()
